# %% [markdown]
# <a href="https://colab.research.google.com/github/IdeaTechsquad/DSPL-Main/blob/main/Final_model_deploy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
testdf = pd.read_csv("/content/cleaned_test_data.csv")
testdf.head()
# Out:
#    Customer_ID  outlet_city_0  outlet_city_1  outlet_city_2  outlet_city_3  \
# 0        33574              0              0              0              0
# 1        10089              0              0              0              0
# 2        38329              0              0              0              0
# 3        11376              0              0              0              0
# 4        12410              0              0              0              0
#
#    outlet_city_4  luxury_sales  fresh_sales  dry_sales
# 0              1      0.980587     0.041945   1.631089
# 1              1     -0.004228    -0.156121   1.057080
# 2              1     -0.881896    -0.418874   0.268677
# 3              1     -0.084970    -0.206476   1.026638
# 4              1     -0.693814    -0.364431   0.312021

# %%
#filter
filter_test = testdf[['luxury_sales','fresh_sales','dry_sales','outlet_city_0','outlet_city_1','outlet_city_2','outlet_city_3','outlet_city_4']]

# %%
import pickle
final_model = pickle.load(open("/content/Finalized_lightGBM_model.sav", 'rb'))

# %%
predictions = final_model.predict(filter_test)
predicted_classes = np.argmax(predictions, axis=1)

# %%
final_output_df =pd.DataFrame({'Customer_ID': testdf['Customer_ID'], 'cluster_category': predicted_classes})

print(final_output_df)
# Out:
#        Customer_ID  cluster_category
# 0            33574                 0
# 1            10089                 0
# 2            38329                 0
# 3            11376                 0
# 4            12410                 0
# ...            ...               ...
# 40744        33698                 0
# 40745         4185                 0
# 40746        28664                 0
# 40747        11874                 1
# 40748        11431                 1
#
# [40749 rows x 2 columns]

# %%
final_output_df.to_csv('cluster_predictions.csv', index=False)
